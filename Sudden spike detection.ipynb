# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes
def detect_spikes(prices, timestamps, slope_threshold=15, pip_threshold=1000):
    spikes = []
    for i in range(1, len(prices)):
        slope = calculate_slope(prices[i-1], prices[i], (timestamps[i] - timestamps[i-1]).total_seconds() / 60)
        pip_change = abs(prices[i] - prices[i-1]) * 10000  # Convert to pips
        if slope > slope_threshold and pip_change > pip_threshold:
            spikes.append((timestamps[i], prices[i], slope, pip_change))
    return spikes

# Function to fetch minute-level data using yfinance
def fetch_data(symbol="EURUSD=X", start_date="2024-08-07", end_date="2024-08-18"):
    data = yf.download(symbol, start=start_date, end=end_date, interval="1m")
    return data

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='USD/USE Price')
    
    # Highlight spikes
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    plt.title(f"USD/USE Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date
def analyze_date(date_str, symbol="EURUSD=X"):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = date - timedelta(days=30)
    end_date = date + timedelta(days=1)
    
    # Fetch data for the past month
    data = fetch_data(symbol=symbol, start_date=start_date.strftime('%Y-%m-%d'), end_date=end_date.strftime('%Y-%m-%d'))
    
    # Filter data for the specific date
    data_on_date = data.loc[data.index.date == date.date()]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
    else:
        print(f"No significant spikes detected on {date_str}.")
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, date_str)

# Example usage: Analyze data and plot spikes for a specific date
date_input = "2024-08-15"  # Example date
analyze_date(date_input)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EURUSD=X']: YFChartError('%ticker%: 1m data not available for startTime=1721084400 and endTime=1723762800. Only 7 days worth of 1m granularity data are allowed to be fetched per request.')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 75
#      73 # Example usage: Analyze data and plot spikes for a specific date
#      74 date_input = "2024-08-15"  # Example date
# ---> 75 analyze_date(date_input)
#
# Cell In[2], line 52, in analyze_date(date_str, symbol)
#      49 data = fetch_data(symbol=symbol, start_date=start_date.strftime('%Y-%m-%d'), end_date=end_date.strftime('%Y-%m-%d'))
#      51 # Filter data for the specific date
# ---> 52 data_on_date = data.loc[data.index.date == date.date()]
#      54 if data_on_date.empty:
#      55     print(f"No data found for {date_str}.")
#
# AttributeError: 'Index' object has no attribute 'date'

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes
def detect_spikes(prices, timestamps, slope_threshold=15, pip_threshold=1000):
    spikes = []
    for i in range(1, len(prices)):
        slope = calculate_slope(prices[i-1], prices[i], (timestamps[i] - timestamps[i-1]).total_seconds() / 60)
        pip_change = abs(prices[i] - prices[i-1]) * 10000  # Convert to pips
        if slope > slope_threshold and pip_change > pip_threshold:
            spikes.append((timestamps[i], prices[i], slope, pip_change))
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="EURUSD=X", start_date="2024-08-07", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="1m")
        all_data.append(data)
        current_start = current_end

    return pd.concat(all_data)

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='USD/USE Price')
    
    # Highlight spikes
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    plt.title(f"USD/USE Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date
def analyze_date(date_str, symbol="EURUSD=X"):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    # Filter data for the specific date
    data_on_date = data[data.index.date == date.date()]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
    else:
        print(f"No significant spikes detected on {date_str}.")
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, date_str)

# Example usage: Analyze data and plot spikes for a specific date
date_input = "2024-08-15"  # Example date
analyze_date(date_input)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['EURUSD=X']: YFChartError('%ticker%: 1m data not available for startTime=1721084400 and endTime=1721689200. The requested range must be within the last 30 days.')
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# C:\Users\harsh\AppData\Local\Temp\ipykernel_11388\1569967013.py:33: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   return pd.concat(all_data)
# No significant spikes detected on 2024-08-15.

# %%
2024-8-10
# Out:
# 2006

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=9, pip_threshold=750):
    spikes = []
    for i in range(1, len(prices)):
        slope = calculate_slope(prices[i-1], prices[i], (timestamps[i] - timestamps[i-1]).total_seconds() / 60)
        pip_change = abs(prices[i] - prices[i-1]) * 10000  # Convert to pips
        if slope > slope_threshold and pip_change > pip_threshold:
            spikes.append((timestamps[i], prices[i], slope, pip_change))
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="XAUUSD=X", start_date="2024-08-01", end_date="2024-08-13"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="1m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        return pd.concat(all_data)
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='XAU/USD Price')
    
    # Highlight spikes
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    plt.title(f"XAU/USD Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date with editable thresholds
def analyze_date(date_str, symbol="XAUUSD=X", slope_threshold=9, pip_threshold=750):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    # Filter data for the specific date
    data_on_date = data[data.index.date == date.date()]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
    else:
        print(f"No significant spikes detected on {date_str}.")
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, date_str)

# Example usage: Analyze data and plot spikes for a specific date with custom thresholds
date_input = "2024-08-12"  # Example date
slope_threshold = 9  # Editable slope threshold
pip_threshold = 750  # Editable pip threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XAUUSD=X']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XAUUSD=X']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XAUUSD=X']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XAUUSD=X']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['XAUUSD=X']: YFTzMissingError('$%ticker%: possibly delisted; No timezone found')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 91
#      89 slope_threshold = 9  # Editable slope threshold
#      90 pip_threshold = 750  # Editable pip threshold
# ---> 91 analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
#
# Cell In[19], line 66, in analyze_date(date_str, symbol, slope_threshold, pip_threshold)
#      63 data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
#      65 # Filter data for the specific date
# ---> 66 data_on_date = data[data.index.date == date.date()]
#      68 if data_on_date.empty:
#      69     print(f"No data found for {date_str}.")
#
# AttributeError: 'RangeIndex' object has no attribute 'date'

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=9, pip_threshold=750):
    spikes = []
    for i in range(1, len(prices)):
        time_diff = (timestamps[i] - timestamps[i-1]).total_seconds() / 60
        slope = calculate_slope(prices[i-1], prices[i], time_diff)
        pip_change = abs(prices[i] - prices[i-1]) * 10000  # Convert to pips
        if slope > slope_threshold and pip_change > pip_threshold:
            spikes.append((timestamps[i], prices[i], slope, pip_change))
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        return pd.concat(all_data)
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)')
    
    # Highlight spikes
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date with editable thresholds
def analyze_date(date_str, symbol="GC=F", slope_threshold=9, pip_threshold=750):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
    else:
        print(f"No significant spikes detected on {date_str}.")
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, date_str)

# Example usage: Analyze data and plot spikes for a specific date with custom thresholds
date_input = "2024-08-12"  # Example date
slope_threshold = 9  # Editable slope threshold
pip_threshold = 750  # Editable pip threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 96
#      94 slope_threshold = 9  # Editable slope threshold
#      95 pip_threshold = 750  # Editable pip threshold
# ---> 96 analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
#
# Cell In[25], line 71, in analyze_date(date_str, symbol, slope_threshold, pip_threshold)
#      68     return
#      70 # Filter data for the specific date
# ---> 71 data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]
#      73 if data_on_date.empty:
#      74     print(f"No data found for {date_str}.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1411, in _LocIndexer._getitem_axis(self, key, axis)
#    1409 if isinstance(key, slice):
#    1410     self._validate_key(key, axis)
# -> 1411     return self._get_slice_axis(key, axis=axis)
#    1412 elif com.is_bool_indexer(key):
#    1413     return self._getbool_axis(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:1443, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1440     return obj.copy(deep=False)
#    1442 labels = obj._get_axis(axis)
# -> 1443 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1445 if isinstance(indexer, slice):
#    1446     return self.obj._slice(indexer, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\datetimes.py:682, in DatetimeIndex.slice_indexer(self, start, end, step)
#     674 # GH#33146 if start and end are combinations of str and None and Index is not
#     675 # monotonic, we can not use Index.slice_indexer because it does not honor the
#     676 # actual elements, is only searching for start and end
#     677 if (
#     678     check_str_or_none(start)
#     679     or check_str_or_none(end)
#     680     or self.is_monotonic_increasing
#     681 ):
# --> 682     return Index.slice_indexer(self, start, end, step)
#     684 mask = np.array(True)
#     685 in_index = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6662, in Index.slice_indexer(self, start, end, step)
#    6618 def slice_indexer(
#    6619     self,
#    6620     start: Hashable | None = None,
#    6621     end: Hashable | None = None,
#    6622     step: int | None = None,
#    6623 ) -> slice:
#    6624     """
#    6625     Compute the slice indexer for input labels and step.
#    6626
#    (...)
#    6660     slice(1, 3, None)
#    6661     """
# -> 6662     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6664     # return a slice
#    6665     if not is_scalar(start_slice):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6879, in Index.slice_locs(self, start, end, step)
#    6877 start_slice = None
#    6878 if start is not None:
# -> 6879     start_slice = self.get_slice_bound(start, "left")
#    6880 if start_slice is None:
#    6881     start_slice = 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6794, in Index.get_slice_bound(self, label, side)
#    6790 original_label = label
#    6792 # For datetime indices label may be a string that has to be converted
#    6793 # to datetime boundary according to its resolution.
# -> 6794 label = self._maybe_cast_slice_bound(label, side)
#    6796 # we need to look up the label
#    6797 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\datetimes.py:643, in DatetimeIndex._maybe_cast_slice_bound(self, label, side)
#     640     label = Timestamp(label).to_pydatetime()
#     642 label = super()._maybe_cast_slice_bound(label, side)
# --> 643 self._data._assert_tzawareness_compat(label)
#     644 return Timestamp(label)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\datetimes.py:786, in DatetimeArray._assert_tzawareness_compat(self, other)
#     782         raise TypeError(
#     783             "Cannot compare tz-naive and tz-aware datetime-like objects."
#     784         )
#     785 elif other_tz is None:
# --> 786     raise TypeError(
#     787         "Cannot compare tz-naive and tz-aware datetime-like objects"
#     788     )
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=9, pip_threshold=750):
    spikes = []
    for i in range(1, len(prices)):
        time_diff = (timestamps[i] - timestamps[i-1]).total_seconds() / 60
        slope = calculate_slope(prices[i-1], prices[i], time_diff)
        pip_change = abs(prices[i] - prices[i-1]) * 10000  # Convert to pips
        if slope > slope_threshold and pip_change > pip_threshold:
            spikes.append((timestamps[i], prices[i], slope, pip_change))
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        combined_data = pd.concat(all_data)
        # Ensure the index is timezone-naive
        combined_data.index = combined_data.index.tz_localize(None)
        return combined_data
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)')
    
    # Highlight spikes
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date with editable thresholds
def analyze_date(date_str, symbol="GC=F", slope_threshold=9, pip_threshold=750):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    date = date.replace(tzinfo=None)  # Ensure date is timezone-naive
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
    else:
        print(f"No significant spikes detected on {date_str}.")
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, date_str)

# Example usage: Analyze data and plot spikes for a specific date with custom thresholds
date_input = "2024-08-12"  # Example date
slope_threshold = 9  # Editable slope threshold
pip_threshold = 750  # Editable pip threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# No significant spikes detected on 2024-08-12.

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=9, pip_threshold=750):
    spikes = []
    for i in range(1, len(prices)):
        time_diff = (timestamps[i] - timestamps[i-1]).total_seconds() / 60
        slope = calculate_slope(prices[i-1], prices[i], time_diff)
        pip_change = abs(prices[i] - prices[i-1]) * 10000  # Convert to pips
        if slope > slope_threshold and pip_change > pip_threshold:
            spikes.append((timestamps[i], prices[i], slope, pip_change))
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        combined_data = pd.concat(all_data)
        # Ensure the index is timezone-naive
        combined_data.index = combined_data.index.tz_localize(None)
        return combined_data
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)', color='blue')

    # Highlight spikes
    spike_times = [spike[0] for spike in spikes]
    spike_prices = [spike[1] for spike in spikes]
    
    plt.scatter(spike_times, spike_prices, color='red', marker='o', s=100, label='Detected Spikes')
    
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date with editable thresholds
def analyze_date(date_str, symbol="GC=F", slope_threshold=3, pip_threshold=200):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    date = date.replace(tzinfo=None)  # Ensure date is timezone-naive
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
    else:
        print(f"No significant spikes detected on {date_str}.")
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, date_str)

# Example usage: Analyze data and plot spikes for a specific date with custom thresholds
date_input = "2024-08-12"  # Example date
slope_threshold = 3  # Editable slope threshold
pip_threshold = 200  # Editable pip threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# No significant spikes detected on 2024-08-12.

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=2, pip_threshold=10, span_minutes=120):
    spikes = []
    time_window = timedelta(minutes=span_minutes)
    
    for i in range(len(prices)):
        start_time = timestamps[i] - time_window
        end_time = timestamps[i]
        time_window_data = [(timestamps[j], prices[j]) for j in range(len(prices)) if start_time <= timestamps[j] <= end_time]
        
        if len(time_window_data) < 2:
            continue
        
        time_window_data.sort()  # Ensure data is sorted by time
        window_prices = [price for _, price in time_window_data]
        window_times = [time for time, _ in time_window_data]
        
        for j in range(1, len(window_prices)):
            time_diff = (window_times[j] - window_times[j-1]).total_seconds() / 60
            slope = calculate_slope(window_prices[j-1], window_prices[j], time_diff)
            pip_change = abs(window_prices[j] - window_prices[j-1]) * 10000  # Convert to pips
            
            if slope > slope_threshold and pip_change > pip_threshold:
                spikes.append((timestamps[i], prices[i], slope, pip_change))
    
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        combined_data = pd.concat(all_data)
        # Ensure the index is timezone-naive
        combined_data.index = combined_data.index.tz_localize(None)
        return combined_data
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, average_spike_time, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)', color='blue')

    # Highlight spikes
    spike_times = [spike[0] for spike in spikes]
    spike_prices = [spike[1] for spike in spikes]
    
    plt.scatter(spike_times, spike_prices, color='red', marker='o', s=100, label='Detected Spikes')
    
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[3]:.0f} pips\nSlope: {spike[2]:.2f}', color='red')

    if average_spike_time:
        plt.axvline(x=average_spike_time, color='green', linestyle='-', lw=1, label='Average Spike Time')
    
    plt.legend()
    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date with editable thresholds
def analyze_date(date_str, symbol="GC=F", slope_threshold=9, pip_threshold=750):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    date = date.replace(tzinfo=None)  # Ensure date is timezone-naive
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}")
        
        # Calculate average spike time
        average_spike_time = np.mean([spike[0].timestamp() for spike in spikes])
        average_spike_time = datetime.fromtimestamp(average_spike_time)

        print(f"Average spike time: {average_spike_time}")
    else:
        print(f"No significant spikes detected on {date_str}.")
        average_spike_time = None
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, average_spike_time, date_str)

# Example usage: Analyze data and plot spikes for a specific date with custom thresholds
date_input = "2024-08-14"  # Example date
slope_threshold = 2  # Editable slope threshold
pip_threshold = 10  # Editable pip threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# No significant spikes detected on 2024-08-14.

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=9, pip_threshold=750, value_threshold=7.2, span_minutes=60):
    spikes = []
    time_window = timedelta(minutes=span_minutes)
    
    for i in range(len(prices)):
        start_time = timestamps[i] - time_window
        end_time = timestamps[i]
        time_window_data = [(timestamps[j], prices[j]) for j in range(len(prices)) if start_time <= timestamps[j] <= end_time]
        
        if len(time_window_data) < 2:
            continue
        
        time_window_data.sort()  # Ensure data is sorted by time
        window_prices = [price for _, price in time_window_data]
        window_times = [time for time, _ in time_window_data]
        
        for j in range(1, len(window_prices)):
            time_diff = (window_times[j] - window_times[j-1]).total_seconds() / 60
            slope = calculate_slope(window_prices[j-1], window_prices[j], time_diff)
            pip_change = abs(window_prices[j] - window_prices[j-1]) * 10000  # Convert to pips
            value_change = abs(window_prices[j] - window_prices[j-1])
            
            if (slope > slope_threshold and pip_change > pip_threshold) or value_change > value_threshold:
                spikes.append((timestamps[i], prices[i], slope, pip_change, value_change))
    
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        combined_data = pd.concat(all_data)
        # Ensure the index is timezone-naive
        combined_data.index = combined_data.index.tz_localize(None)
        return combined_data
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, average_spike_time, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)', color='blue')

    # Highlight spikes
    spike_times = [spike[0] for spike in spikes]
    spike_prices = [spike[1] for spike in spikes]
    
    plt.scatter(spike_times, spike_prices, color='red', marker='o', s=100, label='Detected Spikes')
    
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[4]:.2f} USD\nSlope: {spike[2]:.2f}', color='red')

    if average_spike_time:
        plt.axvline(x=average_spike_time, color='green', linestyle='-', lw=1, label='Average Spike Time')
    
    plt.legend()
    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.grid(True)
    plt.show()

# Function to analyze data and plot spikes for a specific date with editable thresholds
def analyze_date(date_str, symbol="GC=F", slope_threshold=9, pip_threshold=750, value_threshold=4):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    date = date.replace(tzinfo=None)  # Ensure date is timezone-naive
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold, value_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}, Value Change: {spike[4]:.2f} USD")
        
        # Calculate average spike time
        average_spike_time = np.mean([spike[0].timestamp() for spike in spikes])
        average_spike_time = datetime.fromtimestamp(average_spike_time)

        print(f"Average spike time: {average_spike_time}")
    else:
        print(f"No significant spikes detected on {date_str}.")
        average_spike_time = None
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, average_spike_time, date_str)

# Example usage: Analyze data and plot spikes for a specific date with custom thresholds
date_input = "2024-08-14"  # Example date
slope_threshold = 9  # Editable slope threshold
pip_threshold = 750  # Editable pip threshold
value_threshold = 7.2  # Editable value threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold, value_threshold=value_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Spikes detected on 2024-08-14:
#  - Time: 2024-08-14 20:10:00, Price: 2479.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:15:00, Price: 2486.89990234375, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:20:00, Price: 2486.60009765625, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:25:00, Price: 2487.5, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:30:00, Price: 2488.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:35:00, Price: 2490.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:40:00, Price: 2491.0, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:45:00, Price: 2490.199951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:50:00, Price: 2489.39990234375, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:55:00, Price: 2487.300048828125, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 21:00:00, Price: 2489.199951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
# Average spike time: 2024-08-14 20:35:00

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd
import requests

# Your NewsAPI key
NEWS_API_KEY = 'f9b0eabb143d40b38607839bed9562db'

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=5, pip_threshold=750, value_threshold=7.2, span_minutes=60):
    spikes = []
    time_window = timedelta(minutes=span_minutes)
    
    for i in range(len(prices)):
        start_time = timestamps[i] - time_window
        end_time = timestamps[i]
        time_window_data = [(timestamps[j], prices[j]) for j in range(len(prices)) if start_time <= timestamps[j] <= end_time]
        
        if len(time_window_data) < 2:
            continue
        
        time_window_data.sort()  # Ensure data is sorted by time
        window_prices = [price for _, price in time_window_data]
        window_times = [time for time, _ in time_window_data]
        
        for j in range(1, len(window_prices)):
            time_diff = (window_times[j] - window_times[j-1]).total_seconds() / 60
            slope = calculate_slope(window_prices[j-1], window_prices[j], time_diff)
            pip_change = abs(window_prices[j] - window_prices[j-1]) * 10000  # Convert to pips
            value_change = abs(window_prices[j] - window_prices[j-1])
            
            if (slope > slope_threshold and pip_change > pip_threshold) or value_change > value_threshold:
                spikes.append((timestamps[i], prices[i], slope, pip_change, value_change))
    
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        combined_data = pd.concat(all_data)
        # Ensure the index is timezone-naive
        combined_data.index = combined_data.index.tz_localize(None)
        return combined_data
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, average_spike_time, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)', color='blue')

    # Highlight spikes
    spike_times = [spike[0] for spike in spikes]
    spike_prices = [spike[1] for spike in spikes]
    
    plt.scatter(spike_times, spike_prices, color='red', marker='o', s=100, label='Detected Spikes')
    
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[4]:.2f} USD\nSlope: {spike[2]:.2f}', color='red')

    if average_spike_time:
        plt.axvline(x=average_spike_time, color='green', linestyle='-', lw=1, label='Average Spike Time')
    
    plt.legend()
    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.grid(True)
    plt.show()

# Function to fetch news articles related to a spike
def fetch_news(query, from_date, to_date):
    url = f'https://newsapi.org/v2/everything'
    params = {
        'q': query,
        'from': from_date,
        'to': to_date,
        'apiKey': NEWS_API_KEY
    }
    response = requests.get(url, params=params)
    data = response.json()
    
    if data['status'] == 'ok':
        articles = data['articles']
        return articles
    else:
        print("Failed to fetch news:", data.get('message', 'Unknown error'))
        return []

# Function to analyze data, plot spikes, and fetch related news
def analyze_date(date_str, symbol="GC=F", slope_threshold=9, pip_threshold=750, value_threshold=4):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    date = date.replace(tzinfo=None)  # Ensure date is timezone-naive
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold, value_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}, Value Change: {spike[4]:.2f} USD")
        
        # Calculate average spike time
        average_spike_time = np.mean([spike[0].timestamp() for spike in spikes])
        average_spike_time = datetime.fromtimestamp(average_spike_time)

        print(f"Average spike time: {average_spike_time}")

        # Fetch news related to the spikes
        from_date = date.strftime('%Y-%m-%dT%H:%M:%S')
        to_date = (date + timedelta(days=1)).strftime('%Y-%m-%dT%H:%M:%S')
        news = fetch_news("gold price spike", from_date, to_date)

        if news:
            print(f"News articles related to the spikes:")
            for article in news:
                print(f" - {article['title']}: {article['description']} ({article['url']})")
        else:
            print("No news articles found for the given spikes.")
    else:
        print(f"No significant spikes detected on {date_str}.")
        average_spike_time = None
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, average_spike_time, date_str)

# Example usage: Analyze data, plot spikes, and fetch related news for a specific date with custom thresholds
date_input = "2024-08-14"  # Example date
slope_threshold = 5  # Editable slope threshold
pip_threshold = 750  # Editable pip threshold
value_threshold = 7.2  # Editable value threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold, value_threshold=value_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Spikes detected on 2024-08-14:
#  - Time: 2024-08-14 20:10:00, Price: 2479.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:15:00, Price: 2486.89990234375, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:20:00, Price: 2486.60009765625, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:25:00, Price: 2487.5, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:30:00, Price: 2488.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:35:00, Price: 2490.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:40:00, Price: 2491.0, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:45:00, Price: 2490.199951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:50:00, Price: 2489.39990234375, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:55:00, Price: 2487.300048828125, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 21:00:00, Price: 2489.199951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
# Average spike time: 2024-08-14 20:35:00
# News articles related to the spikes:
#  - Economics & Investing For Preppers: Here are the latest news items and commentary on current economics news, market trends, stocks, investing opportunities, and the precious metals markets. In this column, JWR also covers hedges, derivatives, and various obscura. This column emphasizes JWR’s “t… (https://survivalblog.com/2024/08/16/economics-investing-preppers-779/)
#  - Fed rate cut looms—a September slash is expected, but the size of the cut is unknown: The latest consumer price report “checked the box” for the Fed to start cutting rates in September, according to TD Securities’ strategists led by Oscar Munoz and Gennadiy Goldberg. (https://fortune.com/2024/08/14/fed-rate-cut-looms-a-september-slash-is-expected-but-the-size-of-the-cut-is-unknown/)
#  - Share Market Highlights August 14, 2024: Sensex settles 150 pts higher, Nifty above 24,140; IT stocks shine: Sensex, Nifty updates on August 14, 2024: ​BSE Sensex​ ended at 79,105.88, marginally up by 149.85 pts or 0.19%, and ​Nifty 50​ closed at 24,143.75, up by 4.75 pts or 0.02%. Stocks advanced on BSE at 3 pm on August 14, 2024, were 1,454 against 2,440 stocks th… (https://www.thehindubusinessline.com/markets/stock-market-highlights-14-august-2024/article68520183.ece)

# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import pandas as pd
import requests

# Your NewsAPI key
NEWS_API_KEY = 'f9b0eabb143d40b38607839bed9562db'

# Function to calculate slope between two points
def calculate_slope(price1, price2, time_diff):
    return (price2 - price1) / time_diff

# Function to detect spikes with editable thresholds
def detect_spikes(prices, timestamps, slope_threshold=9, pip_threshold=750, value_threshold=7.2, span_minutes=30):
    spikes = []
    time_window = timedelta(minutes=span_minutes)
    
    for i in range(len(prices)):
        start_time = timestamps[i] - time_window
        end_time = timestamps[i]
        time_window_data = [(timestamps[j], prices[j]) for j in range(len(prices)) if start_time <= timestamps[j] <= end_time]
        
        if len(time_window_data) < 2:
            continue
        
        time_window_data.sort()  # Ensure data is sorted by time
        window_prices = [price for _, price in time_window_data]
        window_times = [time for time, _ in time_window_data]
        
        for j in range(1, len(window_prices)):
            time_diff = (window_times[j] - window_times[j-1]).total_seconds() / 60
            slope = calculate_slope(window_prices[j-1], window_prices[j], time_diff)
            pip_change = abs(window_prices[j] - window_prices[j-1]) * 10000  # Convert to pips
            value_change = abs(window_prices[j] - window_prices[j-1])
            
            if (slope > slope_threshold and pip_change > pip_threshold) or value_change > value_threshold:
                spikes.append((timestamps[i], prices[i], slope, pip_change, value_change))
    
    return spikes

# Function to fetch minute-level data in chunks
def fetch_data(symbol="GC=F", start_date="2024-07-18", end_date="2024-08-18"):
    all_data = []
    current_start = datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.strptime(end_date, '%Y-%m-%d')

    while current_start < end_date:
        current_end = min(current_start + timedelta(days=7), end_date)
        data = yf.download(symbol, start=current_start.strftime('%Y-%m-%d'), end=current_end.strftime('%Y-%m-%d'), interval="5m")
        if not data.empty:
            all_data.append(data)
        current_start = current_end

    if all_data:
        combined_data = pd.concat(all_data)
        # Ensure the index is timezone-naive
        combined_data.index = combined_data.index.tz_localize(None)
        return combined_data
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no data was collected

# Function to plot data and highlight spikes
def plot_data_with_spikes(data, spikes, average_spike_time, date_str):
    plt.figure(figsize=(12, 6))
    plt.plot(data.index, data['Close'], label='Gold Price (GC=F)', color='blue')

    # Highlight spikes
    spike_times = [spike[0] for spike in spikes]
    spike_prices = [spike[1] for spike in spikes]
    
    plt.scatter(spike_times, spike_prices, color='red', marker='o', s=100, label='Detected Spikes')
    
    for spike in spikes:
        plt.axvline(x=spike[0], color='red', linestyle='--', lw=1)
        plt.text(spike[0], spike[1], f'Spike: {spike[4]:.2f} USD\nSlope: {spike[2]:.2f}', color='red')

    if average_spike_time:
        plt.axvline(x=average_spike_time, color='green', linestyle='-', lw=1, label='Average Spike Time')
    
    plt.legend()
    plt.title(f"Gold Price on {date_str} with Spikes Highlighted")
    plt.xlabel("Time")
    plt.ylabel("Price")
    plt.grid(True)
    plt.show()

# Function to fetch news articles published before a spike
def fetch_news(query, spike_time, hours_before_spike=2):
    from_time = spike_time - timedelta(hours=hours_before_spike)
    url = f'https://newsapi.org/v2/everything'
    params = {
        'q': query,
        'from': from_time.strftime('%Y-%m-%dT%H:%M:%S'),
        'to': spike_time.strftime('%Y-%m-%dT%H:%M:%S'),
        'apiKey': NEWS_API_KEY
    }
    response = requests.get(url, params=params)
    data = response.json()
    
    if data['status'] == 'ok':
        articles = data['articles']
        return articles
    else:
        print("Failed to fetch news:", data.get('message', 'Unknown error'))
        return []

# Function to analyze data, plot spikes, and fetch related news
def analyze_date(date_str, symbol="GC=F", slope_threshold=9, pip_threshold=750, value_threshold=4):
    date = datetime.strptime(date_str, '%Y-%m-%d')
    start_date = (date - timedelta(days=30)).strftime('%Y-%m-%d')
    end_date = (date + timedelta(days=1)).strftime('%Y-%m-%d')
    
    # Fetch data for the past month in chunks
    data = fetch_data(symbol=symbol, start_date=start_date, end_date=end_date)
    
    if data.empty:
        print(f"No data found for {date_str}.")
        return

    # Filter data for the specific date
    date = date.replace(tzinfo=None)  # Ensure date is timezone-naive
    data_on_date = data.loc[date.date():date.date() + timedelta(days=1)]

    if data_on_date.empty:
        print(f"No data found for {date_str}.")
        return

    # Detect spikes with the provided thresholds
    prices = data_on_date['Close'].tolist()
    timestamps = data_on_date.index.to_pydatetime()
    spikes = detect_spikes(prices, timestamps, slope_threshold, pip_threshold, value_threshold)

    if spikes:
        print(f"Spikes detected on {date_str}:")
        for spike in spikes:
            print(f" - Time: {spike[0]}, Price: {spike[1]}, Slope: {spike[2]:.2f}, Pips: {spike[3]:.0f}, Value Change: {spike[4]:.2f} USD")
        
        # Calculate average spike time
        average_spike_time = np.mean([spike[0].timestamp() for spike in spikes])
        average_spike_time = datetime.fromtimestamp(average_spike_time)

        print(f"Average spike time: {average_spike_time}")

        # Fetch news related to the spikes published before the spike time
        for spike in spikes:
            spike_time = spike[0]
            news = fetch_news("gold price", spike_time, hours_before_spike=2)

            if news:
                print(f"News articles related to the spike at {spike_time}:")
                for article in news:
                    print(f" - {article['title']}: {article['description']} ({article['url']})")
            else:
                print(f"No news articles found for the spike at {spike_time}.")
    else:
        print(f"No significant spikes detected on {date_str}.")
        average_spike_time = None
    
    # Plot data with spikes highlighted
    plot_data_with_spikes(data_on_date, spikes, average_spike_time, date_str)

# Example usage: Analyze data, plot spikes, and fetch related news for a specific date with custom thresholds
date_input = "2024-08-14"  # Example date
slope_threshold = 9  # Editable slope threshold
pip_threshold = 750  # Editable pip threshold
value_threshold = 7.2  # Editable value threshold
analyze_date(date_input, slope_threshold=slope_threshold, pip_threshold=pip_threshold, value_threshold=value_threshold)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Spikes detected on 2024-08-14:
#  - Time: 2024-08-14 20:10:00, Price: 2479.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:15:00, Price: 2486.89990234375, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:20:00, Price: 2486.60009765625, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:25:00, Price: 2487.5, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
#  - Time: 2024-08-14 20:30:00, Price: 2488.699951171875, Slope: -0.75, Pips: 75000, Value Change: 7.50 USD
# Average spike time: 2024-08-14 20:20:00
# News articles related to the spike at 2024-08-14 20:10:00:
#  - A rosé by any other name: Veteran Boston tech entrepreneurs launch winemaking business: Even for Amy and Pierre Villenueve, a couple hardened by years of starting, running, and working in tech startups, winemaking presented a new set of risks. (https://www.bostonglobe.com/2024/08/14/business/domaine-travelle-wine-vineyard-france-rose-amy-pierre-villenueve/)
#  - Earnings call: Franco-Nevada reports growth amid acquisitions: Earnings call: Franco-Nevada reports growth amid acquisitions (https://www.investing.com/news/stock-market-news/earnings-call-franconevada-reports-growth-amid-acquisitions-93CH-3572091)
#  - Is This the ‘Halloween’ Version of Ja Morant’s New Signature Sneaker?: Another new Nike Ja 2 style surfaces ahead of the model's official unveiling. (http://footwearnews.com/shoes/sneaker-news/nike-ja-2-halloween-hq2638-600-1203676804/)
#  - Fantasy Football Today: Kyle Pitts is a perfect storm sleeper, while Xavier Worthy's role may increase, more: Jacob Gibbs unveils his updated sleepers ahead of the 2024 season (https://www.cbssports.com/fantasy/football/news/fantasy-football-today-kyle-pitts-is-a-perfect-storm-sleeper-while-xavier-worthys-role-may-increase-more/)
#  - How new broker commission rules could affect homebuyers and sellers: Beginning Saturday, sellers won't automatically have to pay the commissions for agents on both sides of a home sale. (https://buffalonews.com/news/local/business/real-estate/buffalo-real-estate-home-buying-broker-commissions/article_0f598946-5338-11ef-bac9-dbd6297a12a3.html)
# News articles related to the spike at 2024-08-14 20:15:00:
#  - These Popular Keepsake Mason Jars Are the Cutest I’ve Ever Seen: More than 2,000 were sold last month!
# READ MORE... (https://www.thekitchn.com/ball-honeybee-keepsake-mason-jars-amazon-reviews-23674742)
#  - A rosé by any other name: Veteran Boston tech entrepreneurs launch winemaking business: Even for Amy and Pierre Villenueve, a couple hardened by years of starting, running, and working in tech startups, winemaking presented a new set of risks. (https://www.bostonglobe.com/2024/08/14/business/domaine-travelle-wine-vineyard-france-rose-amy-pierre-villenueve/)
#  - Earnings call: Franco-Nevada reports growth amid acquisitions: Earnings call: Franco-Nevada reports growth amid acquisitions (https://www.investing.com/news/stock-market-news/earnings-call-franconevada-reports-growth-amid-acquisitions-93CH-3572091)
#  - Is This the ‘Halloween’ Version of Ja Morant’s New Signature Sneaker?: Another new Nike Ja 2 style surfaces ahead of the model's official unveiling. (http://footwearnews.com/shoes/sneaker-news/nike-ja-2-halloween-hq2638-600-1203676804/)
#  - Stock market today: Stocks climb after inflation drops to 3-year low, solidifying Fed bets: Investors are pricing in with certainty that a rate cut is coming in September, per the CME FedWatch tool. (https://markets.businessinsider.com/news/stocks/inflation-report-stock-market-today-fed-rate-cuts-outlook-economy-2024-8)
#  - Fantasy Football Today: Kyle Pitts is a perfect storm sleeper, while Xavier Worthy's role may increase, more: Jacob Gibbs unveils his updated sleepers ahead of the 2024 season (https://www.cbssports.com/fantasy/football/news/fantasy-football-today-kyle-pitts-is-a-perfect-storm-sleeper-while-xavier-worthys-role-may-increase-more/)
#  - How new broker commission rules could affect homebuyers and sellers: Beginning Saturday, sellers won't automatically have to pay the commissions for agents on both sides of a home sale. (https://buffalonews.com/news/local/business/real-estate/buffalo-real-estate-home-buying-broker-commissions/article_0f598946-5338-11ef-bac9-dbd6297a12a3.html)
# News articles related to the spike at 2024-08-14 20:20:00:
#  - These Popular Keepsake Mason Jars Are the Cutest I’ve Ever Seen: More than 2,000 were sold last month!
# READ MORE... (https://www.thekitchn.com/ball-honeybee-keepsake-mason-jars-amazon-reviews-23674742)
#  - A rosé by any other name: Veteran Boston tech entrepreneurs launch winemaking business: Even for Amy and Pierre Villenueve, a couple hardened by years of starting, running, and working in tech startups, winemaking presented a new set of risks. (https://www.bostonglobe.com/2024/08/14/business/domaine-travelle-wine-vineyard-france-rose-amy-pierre-villenueve/)
#  - Earnings call: Franco-Nevada reports growth amid acquisitions: Earnings call: Franco-Nevada reports growth amid acquisitions (https://www.investing.com/news/stock-market-news/earnings-call-franconevada-reports-growth-amid-acquisitions-93CH-3572091)
#  - Is This the ‘Halloween’ Version of Ja Morant’s New Signature Sneaker?: Another new Nike Ja 2 style surfaces ahead of the model's official unveiling. (http://footwearnews.com/shoes/sneaker-news/nike-ja-2-halloween-hq2638-600-1203676804/)
#  - Stock market today: Stocks climb after inflation drops to 3-year low, solidifying Fed bets: Investors are pricing in with certainty that a rate cut is coming in September, per the CME FedWatch tool. (https://markets.businessinsider.com/news/stocks/inflation-report-stock-market-today-fed-rate-cuts-outlook-economy-2024-8)
#  - Fantasy Football Today: Kyle Pitts is a perfect storm sleeper, while Xavier Worthy's role may increase, more: Jacob Gibbs unveils his updated sleepers ahead of the 2024 season (https://www.cbssports.com/fantasy/football/news/fantasy-football-today-kyle-pitts-is-a-perfect-storm-sleeper-while-xavier-worthys-role-may-increase-more/)
#  - How new broker commission rules could affect homebuyers and sellers: Beginning Saturday, sellers won't automatically have to pay the commissions for agents on both sides of a home sale. (https://buffalonews.com/news/local/business/real-estate/buffalo-real-estate-home-buying-broker-commissions/article_0f598946-5338-11ef-bac9-dbd6297a12a3.html)
# News articles related to the spike at 2024-08-14 20:25:00:
#  - These Popular Keepsake Mason Jars Are the Cutest I’ve Ever Seen: More than 2,000 were sold last month!
# READ MORE... (https://www.thekitchn.com/ball-honeybee-keepsake-mason-jars-amazon-reviews-23674742)
#  - A rosé by any other name: Veteran Boston tech entrepreneurs launch winemaking business: Even for Amy and Pierre Villenueve, a couple hardened by years of starting, running, and working in tech startups, winemaking presented a new set of risks. (https://www.bostonglobe.com/2024/08/14/business/domaine-travelle-wine-vineyard-france-rose-amy-pierre-villenueve/)
#  - 5 things to watch on the ASX 200 on Thursday: Another positive session is expected for Aussie investors today.
# The post 5 things to watch on the ASX 200 on Thursday appeared first on The Motley Fool Australia. (https://www.fool.com.au/2024/08/15/5-things-to-watch-on-the-asx-200-on-thursday-231/)
#  - Earnings call: Franco-Nevada reports growth amid acquisitions: Earnings call: Franco-Nevada reports growth amid acquisitions (https://www.investing.com/news/stock-market-news/earnings-call-franconevada-reports-growth-amid-acquisitions-93CH-3572091)
#  - Is This the ‘Halloween’ Version of Ja Morant’s New Signature Sneaker?: Another new Nike Ja 2 style surfaces ahead of the model's official unveiling. (http://footwearnews.com/shoes/sneaker-news/nike-ja-2-halloween-hq2638-600-1203676804/)
#  - Stock market today: Stocks climb after inflation drops to 3-year low, solidifying Fed bets: Investors are pricing in with certainty that a rate cut is coming in September, per the CME FedWatch tool. (https://markets.businessinsider.com/news/stocks/inflation-report-stock-market-today-fed-rate-cuts-outlook-economy-2024-8)
#  - Fantasy Football Today: Kyle Pitts is a perfect storm sleeper, while Xavier Worthy's role may increase, more: Jacob Gibbs unveils his updated sleepers ahead of the 2024 season (https://www.cbssports.com/fantasy/football/news/fantasy-football-today-kyle-pitts-is-a-perfect-storm-sleeper-while-xavier-worthys-role-may-increase-more/)
#  - How new broker commission rules could affect homebuyers and sellers: Beginning Saturday, sellers won't automatically have to pay the commissions for agents on both sides of a home sale. (https://buffalonews.com/news/local/business/real-estate/buffalo-real-estate-home-buying-broker-commissions/article_0f598946-5338-11ef-bac9-dbd6297a12a3.html)
# News articles related to the spike at 2024-08-14 20:30:00:
#  - These Popular Keepsake Mason Jars Are the Cutest I’ve Ever Seen: More than 2,000 were sold last month!
# READ MORE... (https://www.thekitchn.com/ball-honeybee-keepsake-mason-jars-amazon-reviews-23674742)
#  - A rosé by any other name: Veteran Boston tech entrepreneurs launch winemaking business: Even for Amy and Pierre Villenueve, a couple hardened by years of starting, running, and working in tech startups, winemaking presented a new set of risks. (https://www.bostonglobe.com/2024/08/14/business/domaine-travelle-wine-vineyard-france-rose-amy-pierre-villenueve/)
#  - 5 things to watch on the ASX 200 on Thursday: Another positive session is expected for Aussie investors today.
# The post 5 things to watch on the ASX 200 on Thursday appeared first on The Motley Fool Australia. (https://www.fool.com.au/2024/08/15/5-things-to-watch-on-the-asx-200-on-thursday-231/)
#  - Earnings call: Franco-Nevada reports growth amid acquisitions: Earnings call: Franco-Nevada reports growth amid acquisitions (https://www.investing.com/news/stock-market-news/earnings-call-franconevada-reports-growth-amid-acquisitions-93CH-3572091)
#  - Is This the ‘Halloween’ Version of Ja Morant’s New Signature Sneaker?: Another new Nike Ja 2 style surfaces ahead of the model's official unveiling. (http://footwearnews.com/shoes/sneaker-news/nike-ja-2-halloween-hq2638-600-1203676804/)
#  - Stock market today: Stocks climb after inflation drops to 3-year low, solidifying Fed bets: Investors are pricing in with certainty that a rate cut is coming in September, per the CME FedWatch tool. (https://markets.businessinsider.com/news/stocks/inflation-report-stock-market-today-fed-rate-cuts-outlook-economy-2024-8)
#  - Fantasy Football Today: Kyle Pitts is a perfect storm sleeper, while Xavier Worthy's role may increase, more: Jacob Gibbs unveils his updated sleepers ahead of the 2024 season (https://www.cbssports.com/fantasy/football/news/fantasy-football-today-kyle-pitts-is-a-perfect-storm-sleeper-while-xavier-worthys-role-may-increase-more/)
#  - How new broker commission rules could affect homebuyers and sellers: Beginning Saturday, sellers won't automatically have to pay the commissions for agents on both sides of a home sale. (https://buffalonews.com/news/local/business/real-estate/buffalo-real-estate-home-buying-broker-commissions/article_0f598946-5338-11ef-bac9-dbd6297a12a3.html)
